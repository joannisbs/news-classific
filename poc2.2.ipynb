# %%
import pandas as pd
import numpy as np
from utilsPtBr import Utils
import re

dataPath = 'data/shortCorpus2.csv'
df_uf = pd.read_csv(dataPath, sep=';')
util = Utils()

# %%
dictDataframeTreino = {
    "tag": [],
    "text": [],
}

dictDataframeTeste = {
    "tag": [],
    "text": [], 
}

dictDataframeWithoutAnothersTreino = {
    "tag": [],
    "text": [],
}

dictDataframeWithoutAnothersTeste = {
    "tag": [],
    "text": [], 
}


formatTag = {
    "Publicação - Despacho / Decisão": 1,
    "Publicação - Sentença": 2,
    "Publicação - Audiência": 3,
}

# %%
from random import randint
def calcTestLineAleatory():
    numberAleatory = randint(0,99);
    if numberAleatory % 9 == 1: 
        return True;
    return False;

# %%
# pre formatando texto e separando treino e teste
vocabulary = {
    'UNKNOWN': 'UNKNOWN'
}

for i in range (len(df_uf.index)):
    tag = df_uf.loc[i].iloc[1]
    tag = formatTag.get(tag, 0)
  
    text = df_uf.loc[i].iloc[2]
    tokens = util.tokenize(text)
    for tok in set(tokens):
        if bool(re.search(r'\d', tok)):
            vocabulary['NUMBER'] = tok
        else:  
            vocabulary[tok] = tok
    #freq = util.getPropoFreq(tokens)
  
    if calcTestLineAleatory():
        dictDataframeTeste['tag'].append(tag)
        dictDataframeTeste['text'].append(tokens)
    else:
        dictDataframeTreino['tag'].append(tag)
        dictDataframeTreino['text'].append(tokens)
    if tag != 0:
        if calcTestLineAleatory():
            dictDataframeWithoutAnothersTeste['tag'].append(tag)
            dictDataframeWithoutAnothersTeste['text'].append(tokens)
        else:
            dictDataframeWithoutAnothersTreino['tag'].append(tag)
            dictDataframeWithoutAnothersTreino['text'].append(tokens)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-82b22045e44b> in <module>
#       9
#      10     text = df_uf.loc[i].iloc[2]
# ---> 11     tokens = util.tokenize(text)
#      12     for tok in set(tokens):
#      13         if bool(re.search(r'\d', tok)):
#
# ~/projetos/facu/piln/projeto/utilsPtBr.py in tokenize(self, text)
#      22     textFormated = text.lower()
#      23     tokens = []
# ---> 24     for token in nltk.word_tokenize(textFormated):
#      25       tokens.append(token.lower())
#      26     tokens = [word for word in tokens if word not in stopwords and word not in ponctuation]
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     """
#     106     tokenizer = load("tokenizers/punkt/{0}.pickle".format(language))
# --> 107     return tokenizer.tokenize(text)
#     108
#     109
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1270         Given a text, returns a list of the sentences in that text.
#    1271         """
# -> 1272         return list(self.sentences_from_text(text, realign_boundaries))
#    1273
#    1274     def debug_decisions(self, text):
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1324         follows the period.
#    1325         """
# -> 1326         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1327
#    1328     def _slices_from_text(self, text):
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1324         follows the period.
#    1325         """
# -> 1326         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1327
#    1328     def _slices_from_text(self, text):
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1314         if realign_boundaries:
#    1315             slices = self._realign_boundaries(text, slices)
# -> 1316         for sl in slices:
#    1317             yield (sl.start, sl.stop)
#    1318
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1362                 continue
#    1363
# -> 1364             m = self._lang_vars.re_boundary_realignment.match(text[sl2])
#    1365             if m:
#    1366                 yield slice(sl1.start, sl2.start + len(m.group(0).rstrip()))
#
# KeyboardInterrupt:

# %%
vocabulary["UNKNOWN"] = "UNKNOWN"
print('size of vocanulary is ' + str(len(vocabulary.keys())) + ' words!')

word2index = {}
def get_word_2_index(vocab):
    for i,word in enumerate(vocab):
        if any(char.isdigit() for char in tok):
            word2index['NUMBER'] = i 
        else: 
            word2index[word] = i
    return word2index

word2index = get_word_2_index(vocabulary.keys())

print(word2index["UNKNOWN"])
def text_to_vector(tokens):
    totalUnknow = 0;
    layer = np.zeros(len(vocabulary.keys()),dtype=float)
    for word in tokens:
        index = word2index.get(word, word2index["UNKNOWN"])
        
        if any(char.isdigit() for char in word):
            index = word2index["NUMBER"]

        layer[index] += 1
        if index ==  word2index["UNKNOWN"]:
            totalUnknow += 1
#    if(totalUnknow> 0):        
#        print('total de palavras desconhecidas no vocabulario: ' + str(totalUnknow))
    return layer
# Out:
# size of vocanulary is 27817 words!
# 0

# %%
textsTreino = []
tagsTreino = []
textsTest = []
tagsTest = []
textsWOTreino = []
tagsWOTreino = []
textsWOTest = []
tagsWOTest = []

for i in range (len(dictDataframeTreino['text'])):
    textsTreino.append(text_to_vector(dictDataframeTreino['text'][i]))
    tagsTreino.append(dictDataframeTreino['tag'][i])

for i in range (len(dictDataframeTeste['text'])):
    textsTest.append(text_to_vector(dictDataframeTeste['text'][i]))
    tagsTest.append(dictDataframeTeste['tag'][i])

for i in range (len(dictDataframeWithoutAnothersTreino['text'])):
    textsWOTreino.append(text_to_vector(dictDataframeWithoutAnothersTreino['text'][i]))
    tagsWOTreino.append(dictDataframeWithoutAnothersTreino['tag'][i])

for i in range (len(dictDataframeWithoutAnothersTeste['text'])):
    textsWOTest.append(text_to_vector(dictDataframeWithoutAnothersTeste['text'][i]))
    tagsWOTest.append(dictDataframeWithoutAnothersTeste['tag'][i])

# %%
print('Total de amostras')
print('treino ' + str(len(tagsTreino)))
print('teste ' + str(len(tagsTest)))
print('treino sem outros ' + str(len(tagsWOTreino)))
print('teste sem outros ' + str(len(tagsWOTest)))
# Out:
# Total de amostras
# treino 8865
# teste 1079
# treino sem outros 8037
# teste sem outros 952

# %%
from sklearnClass import SKLRandomForestClassifier

RandomForestClassifier = SKLRandomForestClassifier()

# %%
RandomForestClassifier.fit(textsTreino, tagsTreino)
RandomForestClassifier.test(textsTest, tagsTest)
# Out:
# score:      83.225%
#               precision    recall  f1-score   support
#
#            0       0.88      0.07      0.13        98
#            1       0.82      0.93      0.87       577
#            2       0.74      0.78      0.76       179
#            3       0.94      0.97      0.95       225
#
#     accuracy                           0.83      1079
#    macro avg       0.84      0.69      0.68      1079
# weighted avg       0.84      0.83      0.80      1079

# %%
RandomForestClassifier.getConfusionMatrix(textsTest, tagsTest)

# %%
# RandomForestClassifier.fit(textsWOTreino, tagsWOTreino)
# RandomForestClassifier.test(textsWOTest, tagsWOTest)
# Out:
# score:      93.172%
#               precision    recall  f1-score   support
#
#            1       0.94      0.95      0.95       583
#            2       0.86      0.84      0.85       189
#            3       0.96      0.98      0.97       180
#
#     accuracy                           0.93       952
#    macro avg       0.92      0.92      0.92       952
# weighted avg       0.93      0.93      0.93       952

# %%
# RandomForestClassifier.getConfusionMatrix(textsWOTest, tagsWOTest)

# %%
RandomForestClassifier.getDecisionTree(vocabulary.keys())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-ea589743de29> in <module>
# ----> 1 RandomForestClassifier.getDecisionTree(vocabulary.keys())
#
# ~/projetos/facu/piln/projeto/sklearnClass.py in getDecisionTree(self, vocabulary)
#      34   def getDecisionTree(self, vocabulary):
#      35     estimator = self.__model_RF.estimators_[5]
# ---> 36     export_graphviz(estimator, out_file='tree.dot',
#      37                 class_names = ['outros', 'decisao', 'sentença', 'audiencia'],
#      38                 feature_names = vocabulary,
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     888             fontname=fontname,
#     889         )
# --> 890         exporter.export(decision_tree)
#     891
#     892         if return_string:
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_export.py in export(self, decision_tree)
#     460             self.recurse(decision_tree, 0, criterion="impurity")
#     461         else:
# --> 462             self.recurse(decision_tree.tree_, 0, criterion=decision_tree.criterion)
#     463
#     464         self.tail()
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     519
#     520             self.out_file.write(
# --> 521                 "%d [label=%s" % (node_id, self.node_to_str(tree, node_id, criterion))
#     522             )
#     523
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_export.py in node_to_str(self, tree, node_id, criterion)
#     290             # Always write node decision criteria, except for leaves
#     291             if self.feature_names is not None:
# --> 292                 feature = self.feature_names[tree.feature[node_id]]
#     293             else:
#     294                 feature = "X%s%s%s" % (
#
# TypeError: 'dict_keys' object is not subscriptable
